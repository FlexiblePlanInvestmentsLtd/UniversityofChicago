# %% [markdown]
# ## Package Import

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import os
from ta.momentum import RSIIndicator, ROCIndicator
from ta.trend import MACD
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
import matplotlib.pyplot as plt
import warnings
import joblib
from utils import *
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Random Seed Setup

# %%
# Set a random seed to ensure repeatable results
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## Data Import

# %%
# Load data
data_path = os.path.dirname(os.getcwd()) + '/data'
data_prefix = '/broad_assets_'

names = ['weekly_rets', 'roc_4w', 'roc_6w', 'roc_12w', 'roc_26w', 'roc_52w', 
         'bb_20d', 'bb_90d', 'bb_180d', 'bb_240d', 'macd', 'rsi', 'ht_transforms', 
         'rolling_vol_20', 'rolling_vol_60', 'rolling_vol_126', 'rolling_vol_252', 'rolling_vol_504',
         'rolling_skew_20', 'rolling_skew_60', 'rolling_skew_126', 'rolling_skew_252', 'rolling_skew_504',
         'rolling_kurt_20', 'rolling_kurt_60', 'rolling_kurt_126', 'rolling_kurt_252', 'rolling_kurt_504',
         'ewma_vol', 'skew', 'kurtosis']
dfs = {}
for name in names:
    dfs[name] = pd.read_excel(data_path + data_prefix + name + '.xlsx', sheet_name=0, index_col=0, parse_dates=True)

# %%
dfs['target'] = dfs.pop('weekly_rets')
dfs['target']
# Out:
#             Asset 1  Asset 2  Asset 3  Asset 4  Asset 5  Asset 6  Asset 7  \
# Date
# 2000-07-31   0.0152   0.0757  -0.0023   0.0009   0.0422   0.0050   0.0373
# 2000-08-07   0.0679   0.0526   0.0159   0.0134   0.0365  -0.0237  -0.0196
# 2000-08-14   0.0157   0.0023   0.0152   0.0063   0.0171   0.0254   0.0294
# 2000-08-21   0.0095   0.0566  -0.0018  -0.0003   0.0068  -0.0264   0.0016
# 2000-08-28   0.0184   0.0653   0.0019   0.0041   0.0379  -0.0353   0.0195
# ...             ...      ...      ...      ...      ...      ...      ...
# 2024-08-12   0.0607   0.0718  -0.0440  -0.0147   0.0210   0.0425   0.0431
# 2024-08-19   0.1006   0.1346   0.0199  -0.0004   0.1037   0.0321   0.0931
# 2024-08-26   0.0020  -0.0266   0.0028   0.0064   0.0450   0.0540   0.0290
# 2024-08-30   0.0108   0.0050  -0.0310  -0.0094  -0.0007   0.0091   0.0127
# 2024-09-06  -0.0841  -0.1162   0.0664   0.0261  -0.1122  -0.0004  -0.0769
#
#             Asset 8  Asset 9  Asset 10  Asset 11
# Date
# 2000-07-31   0.0021  -0.0025   -0.0084   -0.0318
# 2000-08-07  -0.0116   0.0241   -0.0266    0.0346
# 2000-08-14   0.0369   0.0085    0.0063    0.0481
# 2000-08-21  -0.0024   0.0077    0.0018    0.0384
# 2000-08-28  -0.0170   0.0019   -0.0095    0.0313
# ...             ...      ...       ...       ...
# 2024-08-12   0.0882   0.0093    0.0503    0.0583
# 2024-08-19   0.0771  -0.0238    0.0239   -0.0377
# 2024-08-26  -0.0180  -0.0195    0.0097    0.0332
# 2024-08-30  -0.0055   0.0175   -0.0126   -0.0348
# 2024-09-06  -0.0735  -0.0095   -0.0057   -0.0793
#
# [1258 rows x 11 columns]

# %% [markdown]
# ## Breaking out features

# %% [markdown]
# ### MACD

# %%
# MACD dataframe needs to be broken out into 3 separate dataframes
macd_names = ['MACD_Line', 'Signal_Line', 'MACD_Histogram']
for name in macd_names:
    cols = [col for col in dfs['macd'].columns if name in col]
    dfs[name] = dfs['macd'].loc[:, cols]

# %%
del dfs['macd']

# %% [markdown]
# ### RSI

# %%
# RSI dataframe has RSI and Stochastic RSI, break these out into two frames
rsi_cols = [col for col in dfs['rsi'].columns if 'rsi' in col]
stoch_rsi_cols = [col for col in dfs['rsi'].columns if 'stoch_rsi' in col]
rsi_cols = [col for col in rsi_cols if col not in stoch_rsi_cols]   # Removing stochastic rsi column names from rsi

rsi_names = ['stoch_rsi', 'rsi']
rsi_cols = [stoch_rsi_cols, rsi_cols]

for name, cols in zip(rsi_names, rsi_cols):
    dfs[name] = dfs['rsi'].loc[:, cols]

# %% [markdown]
# ### Bollinger Bands

# %%
bb_names = ['sma', 'upper', 'lower']
bb_frames = ['bb_20d', 'bb_90d', 'bb_180d', 'bb_240d']

for frame in bb_frames:
    for name in bb_names:
        cols = [col for col in dfs[frame].columns if name in col]
        dfs[f'{frame}_{name}'] = dfs[frame].loc[:, cols]

# %%
for frame in bb_frames:
    del dfs[frame]

# %% [markdown]
# ### Hilbert Transforms

# %%
# Hilbert Transforms dataframe has five features
ht_names = ['ht_dcperiod', 'ht_dcphase', 'inphase', 'sine', 'ht_trendmode']

for name in ht_names:
    cols = [col for col in dfs['ht_transforms'].columns if name in col]
    dfs[name] = dfs['ht_transforms'].loc[:, cols]

# %%
del dfs['ht_transforms']

# %% [markdown]
# ## Dates Cleanup

# %%
# Get intersection of dates across datasets
dates_inter = reduce(lambda x, y: set(x).intersection(y.index), list(dfs.values())[1:], list(dfs.values())[0].index)
dates_inter = sorted(list(dates_inter))
print(f'Count: {len(dates_inter)}\nFirst: {dates_inter[0]}\nLast:{dates_inter[-1]}')
# Out:
# Count: 1154
# First: 2002-08-05 00:00:00
# Last:2024-09-06 00:00:00

# %%
for name, frame in dfs.items():
    dfs[name] = frame.loc[dates_inter]

# %% [markdown]
# ## Dynamic Rolling Quantile Risk Level Assignments

# %% [markdown]
# $$\text{Portfolio Volatility} = \sqrt{\sum^n_{i = 1}\sum^n_{j = 1}\omega_i\omega_j Cov(\sigma_i, \sigma_j)}$$
# Equal weights in default.

# %%
def calculate_rolling_volatility(df, return_columns, window):
    """
    Calculate rolling volatility for each asset over a specified window.
    
    :param df: DataFrame containing return data
    :param return_columns: List of columns representing asset returns
    :param window: The rolling window period to calculate the volatility
    :return: DataFrame with rolling volatilities for each asset
    """
    vol_df = pd.DataFrame(index=df.index)
    
    for col in return_columns:
        # Calculate rolling standard deviation (volatility) for the given window
        vol_df[f'{col}_Vol'] = df[col].rolling(window=window).std()
    
    return vol_df.dropna()

def calculate_portfolio_volatility(df, asset_columns, window=52, weights=None):
    # Ensure the index is datetime, as 'Date' is used as the index
    if not pd.api.types.is_datetime64_any_dtype(df.index):
        df.index = pd.to_datetime(df['Date'])
    
    num_assets = len(asset_columns)
    
    # Assign equal weights if no weights are provided
    if weights is None:
        weights = np.ones(num_assets) / num_assets
    
    # Ensure weights sum to 1
    weights = np.array(weights)
    if not np.isclose(weights.sum(), 1):
        raise ValueError("Weights must sum to 1.")
    
    # Covariance Matrix
    rolling_cov = df[asset_columns].rolling(window=window).cov()

    portfolio_volatility = []

    for i in range(window, len(df)):
        # Extract the covariance matrix for the current time point
        cov_matrix = rolling_cov.loc[df.index[i]].values.reshape((num_assets, num_assets))

        # Calculate the portfolio variance (weights * cov_matrix * weights.T)
        portfolio_variance = np.dot(weights.T, np.dot(cov_matrix, weights))

        # Calculate the portfolio volatility (square root of variance)
        portfolio_volatility.append(np.sqrt(portfolio_variance))

    portfolio_volatility_series = pd.Series(portfolio_volatility, index=df.index[window:])

    return portfolio_volatility_series

asset_columns = [col for col in dfs['ewma_vol'].columns if col.startswith('EWMA_vol_')]
rolling_window_size = 26 # Set the rolling window to be half year.

# Function to calculate rolling quantiles for volatility thresholds
def calculate_rolling_quantiles(df, asset_columns, window=13, quantiles=[0.1, 0.3, 0.7, 0.9]):
    """
    Calculate rolling quantiles for portfolio volatility over a given window.
    
    :param df: DataFrame containing volatility data
    :param asset_columns: List of columns representing asset volatilities
    :param window: Rolling window period (default is 0.5 year, assuming weekly data, i.e., 26 weeks)
    :param quantiles: Quantiles to calculate for the rolling volatility (default [0.1, 0.3, 0.7, 0.9])
    :return: DataFrame of rolling quantiles
    """
    rolling_quantiles_df = pd.DataFrame(index=df.index[window:], columns=quantiles)
    
    for i in range(window, len(df)):
        rolling_data = df.iloc[i-window:i]
        rolling_volatility = calculate_portfolio_volatility(rolling_data, asset_columns, window=13)
        rolling_quantiles = rolling_volatility.quantile(quantiles)
        rolling_quantiles_df.loc[df.index[i]] = rolling_quantiles.values

    return rolling_quantiles_df

def assign_rolling_risk_levels(vol_series, rolling_quantiles):
    risk_levels = []
    
    for i in range(len(vol_series)):
        if i >= len(rolling_quantiles):
            risk_levels.append(None)
        else:
            quantiles = rolling_quantiles.iloc[i]
            vol = vol_series.iloc[i]
            if vol > quantiles[0.9]:
                risk_levels.append('Extremely High Risk')
            elif vol > quantiles[0.7]:
                risk_levels.append('Moderately High Risk')
            elif vol > quantiles[0.3]:
                risk_levels.append('Moderately Low Risk')
            else:
                risk_levels.append('Extremely Low Risk')
    
    return pd.Series(risk_levels, index=vol_series.index)

# %%
ewma_weekly_vol = dfs['ewma_vol'].reset_index()
# Filter the data for the time range 2002 to 2024
period_data = ewma_weekly_vol[(ewma_weekly_vol['Date'] >= '2003-08-11') & (ewma_weekly_vol['Date'] <= '2024-12-31')]
# Calculate portfolio volatility for the test period
volatility_series = calculate_portfolio_volatility(period_data, asset_columns, window=13)
# Calculate rolling quantiles for the test period with 0.5-year rolling window
rolling_quantile_thresholds = calculate_rolling_quantiles(period_data, asset_columns, window=rolling_window_size)
# Assign risk levels for the test period using rolling quantiles
rolling_risk_levels = assign_rolling_risk_levels(volatility_series, rolling_quantile_thresholds)

# %%
# display(rolling_risk_levels.head(), volatility_series)
risk_levels_df = pd.DataFrame({'Portfolio Volatility': volatility_series, 'Risk Level': rolling_risk_levels})
display(risk_levels_df)
# Out:
#             Portfolio Volatility            Risk Level
# Date
# 2003-11-10                0.0024   Moderately Low Risk
# 2003-11-17                0.0024  Moderately High Risk
# 2003-11-24                0.0024  Moderately High Risk
# 2003-12-01                0.0022   Moderately Low Risk
# 2003-12-08                0.0023  Moderately High Risk
# ...                          ...                   ...
# 2024-08-12                0.0065                  None
# 2024-08-19                0.0070                  None
# 2024-08-26                0.0072                  None
# 2024-08-30                0.0071                  None
# 2024-09-06                0.0071                  None
#
# [1088 rows x 2 columns]

# %% [markdown]
# ## Features Import
#
# ### Feature adjustments based on the Generated Raw Data

# %%
# RSI/stoch_RSI
df_rsi = dfs['rsi']
df_rsi.columns = [f"RSI_Asset {i+1}" for i in range(len(dfs['rsi'].columns))]
df_stoch_rsi = dfs['stoch_rsi']
df_stoch_rsi.columns = [f"stoch_RSI_Asset {i+1}" for i in range(len(dfs['stoch_rsi'].columns))]
# ROC 4/6/12/26/52w
df_roc_4w = dfs['roc_4w']
df_roc_6w = dfs['roc_6w']
df_roc_12w = dfs['roc_12w']
df_roc_26w = dfs['roc_26w']
df_roc_52w = dfs['roc_52w']
# Boilinger Bands lower/sma/upper 20/90/180/240d
df_bb_20d_lower = dfs['bb_20d_lower']
df_bb_20d_sma = dfs['bb_20d_sma']
df_bb_20d_upper = dfs['bb_20d_upper']
df_bb_90d_lower = dfs['bb_90d_lower']
df_bb_90d_sma = dfs['bb_90d_sma']
df_bb_90d_upper = dfs['bb_90d_upper']
df_bb_180d_lower = dfs['bb_180d_lower']
df_bb_180d_sma = dfs['bb_180d_sma']
df_bb_180d_upper = dfs['bb_180d_upper']
df_bb_240d_lower = dfs['bb_240d_lower']
df_bb_240d_sma = dfs['bb_240d_sma']
df_bb_240d_upper = dfs['bb_240d_upper']
# MACD (macd_line, signal_line, macd_histogram)
df_macd_line = dfs['MACD_Line']
df_signal_line = dfs['Signal_Line']
df_macd_histogram = dfs['MACD_Histogram']
# Hilbert Transforms (ht_dcperiod, ht_dcphase, inphase, sine, ht_trendmode)
df_ht_dcperiod = dfs['ht_dcperiod']
df_ht_dcphase = dfs['ht_dcphase']
df_inphase = dfs['inphase']
df_sine = dfs['sine']
df_ht_trendmode = dfs['ht_trendmode']
# Rolling Volatilities (20/60/126/252/504d)
df_rolling_vol_20 = dfs['rolling_vol_20']
df_rolling_vol_60 = dfs['rolling_vol_60']
df_rolling_vol_126 = dfs['rolling_vol_126']
df_rolling_vol_252 = dfs['rolling_vol_252']
df_rolling_vol_504 = dfs['rolling_vol_504']
df_rolling_vol_20.columns = [f"rolling_vol_20_Asset {i+1}" for i in range(len(dfs['rolling_vol_20'].columns))]
df_rolling_vol_60.columns = [f"rolling_vol_60_Asset {i+1}" for i in range(len(dfs['rolling_vol_60'].columns))]
df_rolling_vol_126.columns = [f"rolling_vol_126_Asset {i+1}" for i in range(len(dfs['rolling_vol_126'].columns))]
df_rolling_vol_252.columns = [f"rolling_vol_252_Asset {i+1}" for i in range(len(dfs['rolling_vol_252'].columns))]
df_rolling_vol_504.columns = [f"rolling_vol_504_Asset {i+1}" for i in range(len(dfs['rolling_vol_504'].columns))]
# Rolling Skews (20/60/126/252/504d)
df_rolling_skew_20 = dfs['rolling_skew_20']
df_rolling_skew_60 = dfs['rolling_skew_60']
df_rolling_skew_126 = dfs['rolling_skew_126']
df_rolling_skew_252 = dfs['rolling_skew_252']
df_rolling_skew_504 = dfs['rolling_skew_504']
df_rolling_skew_20.columns = [f"rolling_skew_20_Asset {i+1}" for i in range(len(dfs['rolling_skew_20'].columns))]
df_rolling_skew_60.columns = [f"rolling_skew_60_Asset {i+1}" for i in range(len(dfs['rolling_skew_60'].columns))]
df_rolling_skew_126.columns = [f"rolling_skew_126_Asset {i+1}" for i in range(len(dfs['rolling_skew_126'].columns))]
df_rolling_skew_252.columns = [f"rolling_skew_252_Asset {i+1}" for i in range(len(dfs['rolling_skew_252'].columns))]
df_rolling_skew_504.columns = [f"rolling_skew_504_Asset {i+1}" for i in range(len(dfs['rolling_skew_504'].columns))]
# Rolling Kurtosis (20/60/126/252/504d)
df_rolling_kurt_20 = dfs['rolling_kurt_20']
df_rolling_kurt_60 = dfs['rolling_kurt_60']
df_rolling_kurt_126 = dfs['rolling_kurt_126']
df_rolling_kurt_252 = dfs['rolling_kurt_252']
df_rolling_kurt_504 = dfs['rolling_kurt_504']
df_rolling_kurt_20.columns = [f"rolling_kurtosis_20_Asset {i+1}" for i in range(len(dfs['rolling_kurt_20'].columns))]
df_rolling_kurt_60.columns = [f"rolling_kurtosis_60_Asset {i+1}" for i in range(len(dfs['rolling_kurt_60'].columns))]
df_rolling_kurt_126.columns = [f"rolling_kurtosis_126_Asset {i+1}" for i in range(len(dfs['rolling_kurt_126'].columns))]
df_rolling_kurt_252.columns = [f"rolling_kurtosis_252_Asset {i+1}" for i in range(len(dfs['rolling_kurt_252'].columns))]
df_rolling_kurt_504.columns = [f"rolling_kurtosis_504_Asset {i+1}" for i in range(len(dfs['rolling_kurt_504'].columns))]
# EWMA VOL
df_vol = dfs['ewma_vol']
# Skew
df_skew = dfs['skew']
df_skew.columns = [f"SKEW_Asset {i+1}" for i in range(len(dfs['skew'].columns))]
# Kurtosis
df_kurtosis = dfs['kurtosis']
df_kurtosis.columns = [f"KURTOSIS_Asset {i+1}" for i in range(len(dfs['kurtosis'].columns))]

# %% [markdown]
# ### Features Wrapping Up

# %%
# Features: RSI, ROC, MACD, EWMA, SKEW, KURTOSIS
# ROC 4/6/12/26/52w
# Boilinger Bands lower/sma/upper 20/90/180/240d
# MACD (macd_line, signal_line, macd_histogram)
# Hilbert Transforms (ht_dcperiod, ht_dcphase, inphase, sine, ht_trendmode)
# Rolling Volatilities (20/60/126/252/504d)
combined_df = pd.concat([df_rsi, df_stoch_rsi, df_roc_4w, df_roc_6w, df_roc_12w, df_roc_26w, df_roc_52w, 
                         df_bb_20d_lower, df_bb_20d_sma, df_bb_20d_upper, df_bb_90d_lower, df_bb_90d_sma, df_bb_90d_upper,
                         df_bb_180d_lower, df_bb_180d_sma, df_bb_180d_upper, df_bb_240d_lower, df_bb_240d_sma, df_bb_240d_upper,
                         df_macd_line, df_signal_line, df_macd_histogram, df_ht_dcperiod, df_ht_dcphase, df_inphase, df_sine,
                         df_ht_trendmode, df_rolling_vol_20, df_rolling_vol_60, df_rolling_vol_126, df_rolling_vol_252, df_rolling_vol_504,
                         df_rolling_skew_20, df_rolling_skew_60, df_rolling_skew_126, df_rolling_skew_252, df_rolling_skew_504,
                         df_rolling_kurt_20, df_rolling_kurt_60, df_rolling_kurt_126, df_rolling_kurt_252, df_rolling_kurt_504,
                         df_vol, df_skew, df_kurtosis], axis=1)
metrics_order = ["RSI", "stoch_RSI", "ROC4", "ROC6", "ROC12", "ROC26", "ROC52", "lower20", "sma20", "upper20", 
                 "lower90", "sma90", "upper90", "lower180", "sma180", "upper180", "lower240", "sma240", "upper240",
                 "MACD_Line", "Signal_Line", "MACD_Histogram", "ht_dcperiod", "ht_dcphase", "inphase", "sine", "ht_trendmode",
                 "rolling_vol_20", "rolling_vol_60", "rolling_vol_126", "rolling_vol_252", "rolling_vol_504",
                 "rolling_skew_20", "rolling_skew_60", "rolling_skew_126", "rolling_skew_252", "rolling_skew_504",
                 "rolling_kurtosis_20", "rolling_kurtosis_60", "rolling_kurtosis_126", "rolling_kurtosis_252", "rolling_kurtosis_504",
                 "EWMA_vol", "SKEW", "KURTOSIS"]
# Extract unique asset numbers and metrics from the column names
unique_assets = sorted(set(int(col.split()[-1]) for col in combined_df.columns))
# Generate the correctly ordered columns for each asset by grouping them directly
ordered_columns = [f"{metric}_Asset {asset}" for asset in unique_assets for metric in metrics_order]
# Select only the columns that exist in the data
valid_columns = [col for col in ordered_columns if col in combined_df.columns]
# Reorder the dataframe columns based on this direct, valid list
features = combined_df[valid_columns].dropna()

final_df = pd.concat([features, risk_levels_df], axis = 1)
final_df = final_df.dropna()
final_df
# Out:
#             RSI_Asset 1  stoch_RSI_Asset 1  ROC4_Asset 1  ROC6_Asset 1  \
# Date
# 2003-11-10      51.4365             0.3680        0.0044        0.0834
# 2003-11-17      48.7950             0.0000       -0.0004        0.0204
# 2003-11-24      50.1757             0.3899        0.0427        0.0143
# 2003-12-01      63.1201             0.7460        0.0226        0.0510
# 2003-12-08      64.7689             1.0000        0.0441        0.0780
# ...                 ...                ...           ...           ...
# 2024-05-13      68.5255             0.8488        0.0598       -0.0144
# 2024-05-20      90.7375             1.0000        0.1191        0.0360
# 2024-05-24      73.9980             0.2751        0.0724        0.0931
# 2024-06-03      59.1814             0.1355        0.0383        0.1071
# 2024-06-10      57.8289             0.1038        0.0521        0.0939
#
#             ROC12_Asset 1  ROC26_Asset 1  ROC52_Asset 1  lower20_Asset 1  \
# Date
# 2003-11-10         0.0986         0.2301         0.4155          -0.0265
# 2003-11-17         0.1054         0.2878         0.3323          -0.0278
# 2003-11-24         0.0910         0.2738         0.2618          -0.0285
# 2003-12-01         0.0777         0.2281         0.3023          -0.0275
# 2003-12-08         0.1122         0.2042         0.4284          -0.0279
# ...                   ...            ...            ...              ...
# 2024-05-13         0.0769         0.3747         0.5327          -0.0269
# 2024-05-20         0.0864         0.3373         0.5422          -0.0220
# 2024-05-24         0.0587         0.3336         0.5311          -0.0230
# 2024-06-03         0.0557         0.3110         0.4703          -0.0183
# 2024-06-10         0.0737         0.3193         0.4690          -0.0191
#
#             sma20_Asset 1  upper20_Asset 1  ...  rolling_kurtosis_20_Asset 11  \
# Date                                        ...
# 2003-11-10         0.0003           0.0271  ...                        4.6978
# 2003-11-17         0.0001           0.0280  ...                        3.2259
# 2003-11-24         0.0022           0.0330  ...                        1.1303
# 2003-12-01         0.0020           0.0315  ...                        1.1341
# 2003-12-08         0.0017           0.0312  ...                        0.9591
# ...                   ...              ...  ...                           ...
# 2024-05-13         0.0030           0.0329  ...                        0.7232
# 2024-05-20         0.0057           0.0335  ...                        0.8901
# 2024-05-24         0.0039           0.0307  ...                       -0.4642
# 2024-06-03         0.0030           0.0242  ...                       -0.6154
# 2024-06-10         0.0026           0.0242  ...                       -1.2830
#
#             rolling_kurtosis_60_Asset 11  rolling_kurtosis_126_Asset 11  \
# Date
# 2003-11-10                        3.5043                         1.4362
# 2003-11-17                        3.0690                         1.4965
# 2003-11-24                        2.0971                         1.4780
# 2003-12-01                        2.0946                         1.6244
# 2003-12-08                        1.4852                         1.5612
# ...                                  ...                            ...
# 2024-05-13                        0.4486                         0.3787
# 2024-05-20                        0.3895                         0.1518
# 2024-05-24                        0.1913                         0.1255
# 2024-06-03                       -0.1082                         0.0569
# 2024-06-10                       -0.3682                        -0.3765
#
#             rolling_kurtosis_252_Asset 11  rolling_kurtosis_504_Asset 11  \
# Date
# 2003-11-10                         0.6524                         0.6612
# 2003-11-17                         0.6351                         0.4919
# 2003-11-24                         0.5747                         0.4799
# 2003-12-01                         0.5856                         0.4939
# 2003-12-08                         0.5102                         0.5090
# ...                                   ...                            ...
# 2024-05-13                         0.6037                         2.4291
# 2024-05-20                         0.6927                         2.5387
# 2024-05-24                         0.6703                         2.5024
# 2024-06-03                         0.6018                         2.4731
# 2024-06-10                         0.4437                         2.4032
#
#             EWMA_vol_Asset 11  SKEW_Asset 11  KURTOSIS_Asset 11  \
# Date
# 2003-11-10             0.0533        -0.2921             1.2053
# 2003-11-17             0.0499        -0.2969             1.2111
# 2003-11-24             0.0654        -0.2973             1.1786
# 2003-12-01             0.0605        -0.3010             1.1857
# 2003-12-08             0.0645        -0.2948             1.1694
# ...                       ...            ...                ...
# 2024-05-13             0.0343        -0.3321             3.1927
# 2024-05-20             0.0350        -0.3327             3.1951
# 2024-05-24             0.0365        -0.3322             3.1954
# 2024-06-03             0.0476        -0.3308             3.1889
# 2024-06-10             0.0524        -0.3307             3.1850
#
#             Portfolio Volatility            Risk Level
# Date
# 2003-11-10                0.0024   Moderately Low Risk
# 2003-11-17                0.0024  Moderately High Risk
# 2003-11-24                0.0024  Moderately High Risk
# 2003-12-01                0.0022   Moderately Low Risk
# 2003-12-08                0.0023  Moderately High Risk
# ...                          ...                   ...
# 2024-05-13                0.0030   Extremely High Risk
# 2024-05-20                0.0028  Moderately High Risk
# 2024-05-24                0.0028   Moderately Low Risk
# 2024-06-03                0.0028   Moderately Low Risk
# 2024-06-10                0.0029   Moderately Low Risk
#
# [1075 rows x 497 columns]

# %%
df_target = dfs['target'].loc[final_df.index]  # Adjust the original returns data aligning with the final features data

# %% [markdown]
# 1. Use previous 20-week returns to predict the next week return.
# 2. Target variables are converted to binary: 1 for positive returns and 0 for negative returuns.
# 3. Training & Testing dataset split: 80\% for training and 20\% for testing.

# %%
sequence_length = 20
models = {}
scalers = {}
histories = {}
predictions = {}
binary_predictions = {}
test_dates = None  # Store the dates in the testing set

# Define the columns of features to be used for model training, excluding non-numeric or unnecessary columns
feature_columns = [col for col in final_df.columns if col not in ['Portfolio Volatility', 'Risk Level']]

def create_sequences(features, target, seq_length):
    X = []
    y = []
    for i in range(len(features) - seq_length):
        X.append(features[i:i + seq_length])
        y.append(target[i + seq_length])
    return np.array(X), np.array(y)

assets = df_target.columns[0:]

# %%
# Combine all features and targets for all assets into a unified dataset
all_features = []
all_targets = []

for asset in assets:
    # Define the target variable as the return for the following week
    target = df_target[asset].shift(-1).dropna()

    # Select columns that contain only numeric features
    current_features = features.loc[target.index, feature_columns]
    X, y = create_sequences(current_features.values, target.values, sequence_length)

    # Filtering NA values one more time
    valid_indices = ~np.isnan(y)
    X = X[valid_indices]
    y = y[valid_indices]

    # Target variables converted to binary: 1 for positive returns and 0 for negative returns
    y = (y > 0).astype(int)

    all_features.append(X)
    all_targets.append(y)

# Concatenate all features and targets into unified arrays
X_all = np.concatenate(all_features, axis=0)
y_all = np.concatenate(all_targets, axis=0)

# Manually split training and test sets (80% training, 20% testing)
split_index = int(len(X_all) * 0.8)
X_train, X_test = X_all[:split_index], X_all[split_index:]
y_train, y_test = y_all[:split_index], y_all[split_index:]

# Feature scaling (normalization)
scaler = MinMaxScaler()
X_train_reshaped = X_train.reshape(-1, X_train.shape[-1])
X_train_scaled = scaler.fit_transform(X_train_reshaped).reshape(X_train.shape)

X_test_reshaped = X_test.reshape(-1, X_test.shape[-1])
X_test_scaled = scaler.transform(X_test_reshaped).reshape(X_test.shape)

# Build the integrated RNN model
model = Sequential()
model.add(SimpleRNN(50, return_sequences=True, input_shape=(sequence_length, X_train.shape[2])))
model.add(Dropout(0.5))
model.add(SimpleRNN(50))
model.add(Dense(1, activation='sigmoid'))  # Dichotomized output

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the integrated model
history = model.fit(
    X_train_scaled, y_train,
    epochs=200,  # Number of epochs for training
    batch_size=256,  # Batch size
    validation_split=0.2,  # Ratio of the validation set
    verbose=1  # Show training progress
)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)
print(f'Integrated Model - Loss of the testing set: {loss:.4f}, Accuracy: {accuracy:.4f}')

# Make predictions on the test set
pred_prob = model.predict(X_test_scaled).flatten()

# Convert probabilities to binary predictions (1 or 0)
pred_binary = (pred_prob > 0.5).astype(int)

plt.figure(figsize=(12, 4), dpi=300)
plt.plot(history.history['accuracy'], label='Accuracy of Training Set')
plt.plot(history.history['val_accuracy'], label='Accuracy of Validation Set')
plt.title('Integrated Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4980 - loss: 0.7940 - val_accuracy: 0.5159 - val_loss: 0.7072
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5356 - loss: 0.7058 - val_accuracy: 0.5159 - val_loss: 0.7028
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5210 - loss: 0.7015 - val_accuracy: 0.5159 - val_loss: 0.6953
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5328 - loss: 0.6960 - val_accuracy: 0.5159 - val_loss: 0.6955
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5336 - loss: 0.6947 - val_accuracy: 0.5159 - val_loss: 0.6934
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5363 - loss: 0.6916 - val_accuracy: 0.5159 - val_loss: 0.6972
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5428 - loss: 0.6916 - val_accuracy: 0.5159 - val_loss: 0.6987
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5374 - loss: 0.6909 - val_accuracy: 0.5164 - val_loss: 0.6940
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5429 - loss: 0.6910 - val_accuracy: 0.5159 - val_loss: 0.7035
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5399 - loss: 0.6931 - val_accuracy: 0.5159 - val_loss: 0.6979
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5396 - loss: 0.6901 - val_accuracy: 0.5164 - val_loss: 0.6941
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5442 - loss: 0.6887 - val_accuracy: 0.5175 - val_loss: 0.6932
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5489 - loss: 0.6872 - val_accuracy: 0.5164 - val_loss: 0.6986
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5486 - loss: 0.6876 - val_accuracy: 0.5175 - val_loss: 0.6978
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5465 - loss: 0.6893 - val_accuracy: 0.5175 - val_loss: 0.6993
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5469 - loss: 0.6852 - val_accuracy: 0.5191 - val_loss: 0.6984
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5585 - loss: 0.6841 - val_accuracy: 0.5191 - val_loss: 0.6978
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5599 - loss: 0.6825 - val_accuracy: 0.5197 - val_loss: 0.6975
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5721 - loss: 0.6806 - val_accuracy: 0.5294 - val_loss: 0.6927
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5617 - loss: 0.6833 - val_accuracy: 0.5321 - val_loss: 0.6934
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5639 - loss: 0.6820 - val_accuracy: 0.5342 - val_loss: 0.6956
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5720 - loss: 0.6813 - val_accuracy: 0.5402 - val_loss: 0.6943
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5813 - loss: 0.6757 - val_accuracy: 0.5358 - val_loss: 0.6923
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5784 - loss: 0.6792 - val_accuracy: 0.5423 - val_loss: 0.6961
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5908 - loss: 0.6714 - val_accuracy: 0.5488 - val_loss: 0.6943
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5947 - loss: 0.6682 - val_accuracy: 0.5439 - val_loss: 0.7115
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5955 - loss: 0.6653 - val_accuracy: 0.5375 - val_loss: 0.6992
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5819 - loss: 0.6705 - val_accuracy: 0.5353 - val_loss: 0.7047
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5983 - loss: 0.6637 - val_accuracy: 0.5472 - val_loss: 0.7048
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6080 - loss: 0.6629 - val_accuracy: 0.5482 - val_loss: 0.7100
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6118 - loss: 0.6579 - val_accuracy: 0.5628 - val_loss: 0.7077
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6220 - loss: 0.6519 - val_accuracy: 0.5466 - val_loss: 0.7138
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6205 - loss: 0.6531 - val_accuracy: 0.5493 - val_loss: 0.7075
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6274 - loss: 0.6474 - val_accuracy: 0.5585 - val_loss: 0.7208
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6291 - loss: 0.6452 - val_accuracy: 0.5606 - val_loss: 0.7053
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6369 - loss: 0.6430 - val_accuracy: 0.5585 - val_loss: 0.7145
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6369 - loss: 0.6386 - val_accuracy: 0.5580 - val_loss: 0.7141
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6443 - loss: 0.6327 - val_accuracy: 0.5660 - val_loss: 0.7108
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6418 - loss: 0.6269 - val_accuracy: 0.5639 - val_loss: 0.7094
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6507 - loss: 0.6236 - val_accuracy: 0.5628 - val_loss: 0.7120
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6507 - loss: 0.6247 - val_accuracy: 0.5730 - val_loss: 0.7225
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6516 - loss: 0.6158 - val_accuracy: 0.5633 - val_loss: 0.7105
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6744 - loss: 0.6087 - val_accuracy: 0.5693 - val_loss: 0.7227
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6692 - loss: 0.6128 - val_accuracy: 0.5687 - val_loss: 0.7198
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6755 - loss: 0.6049 - val_accuracy: 0.5806 - val_loss: 0.7224
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6802 - loss: 0.6068 - val_accuracy: 0.5747 - val_loss: 0.7283
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6722 - loss: 0.6102 - val_accuracy: 0.5687 - val_loss: 0.7277
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6762 - loss: 0.6057 - val_accuracy: 0.5827 - val_loss: 0.7270
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6829 - loss: 0.5963 - val_accuracy: 0.5763 - val_loss: 0.7298
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6900 - loss: 0.5953 - val_accuracy: 0.5747 - val_loss: 0.7338
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6865 - loss: 0.5966 - val_accuracy: 0.5822 - val_loss: 0.7197
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6877 - loss: 0.5954 - val_accuracy: 0.5768 - val_loss: 0.7296
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6935 - loss: 0.5927 - val_accuracy: 0.5768 - val_loss: 0.7222
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6929 - loss: 0.5899 - val_accuracy: 0.5790 - val_loss: 0.7334
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6851 - loss: 0.5799 - val_accuracy: 0.5752 - val_loss: 0.7329
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6865 - loss: 0.5853 - val_accuracy: 0.5725 - val_loss: 0.7261
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6892 - loss: 0.5867 - val_accuracy: 0.5817 - val_loss: 0.7291
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6986 - loss: 0.5804 - val_accuracy: 0.5871 - val_loss: 0.7305
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7015 - loss: 0.5734 - val_accuracy: 0.5757 - val_loss: 0.7329
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6921 - loss: 0.5839 - val_accuracy: 0.5806 - val_loss: 0.7333
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6885 - loss: 0.5910 - val_accuracy: 0.5844 - val_loss: 0.7293
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6847 - loss: 0.5901 - val_accuracy: 0.5774 - val_loss: 0.7362
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6790 - loss: 0.6017 - val_accuracy: 0.5790 - val_loss: 0.7345
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6889 - loss: 0.5934 - val_accuracy: 0.5844 - val_loss: 0.7405
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6903 - loss: 0.5833 - val_accuracy: 0.5919 - val_loss: 0.7500
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6933 - loss: 0.5789 - val_accuracy: 0.5747 - val_loss: 0.7401
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6971 - loss: 0.5785 - val_accuracy: 0.5795 - val_loss: 0.7471
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7044 - loss: 0.5763 - val_accuracy: 0.5833 - val_loss: 0.7513
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7102 - loss: 0.5700 - val_accuracy: 0.5817 - val_loss: 0.7579
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7054 - loss: 0.5675 - val_accuracy: 0.5871 - val_loss: 0.7423
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7144 - loss: 0.5666 - val_accuracy: 0.5795 - val_loss: 0.7602
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7155 - loss: 0.5658 - val_accuracy: 0.5849 - val_loss: 0.7416
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7067 - loss: 0.5678 - val_accuracy: 0.5817 - val_loss: 0.7407
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7118 - loss: 0.5627 - val_accuracy: 0.5822 - val_loss: 0.7569
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7109 - loss: 0.5632 - val_accuracy: 0.5881 - val_loss: 0.7581
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7137 - loss: 0.5601 - val_accuracy: 0.5865 - val_loss: 0.7528
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7076 - loss: 0.5605 - val_accuracy: 0.5871 - val_loss: 0.7490
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7139 - loss: 0.5600 - val_accuracy: 0.5914 - val_loss: 0.7468
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7178 - loss: 0.5616 - val_accuracy: 0.5827 - val_loss: 0.7467
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7106 - loss: 0.5603 - val_accuracy: 0.5908 - val_loss: 0.7343
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7122 - loss: 0.5610 - val_accuracy: 0.5806 - val_loss: 0.7415
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7195 - loss: 0.5603 - val_accuracy: 0.5720 - val_loss: 0.7474
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7135 - loss: 0.5601 - val_accuracy: 0.5801 - val_loss: 0.7409
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7105 - loss: 0.5647 - val_accuracy: 0.5962 - val_loss: 0.7230
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7178 - loss: 0.5619 - val_accuracy: 0.5822 - val_loss: 0.7259
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7099 - loss: 0.5612 - val_accuracy: 0.5876 - val_loss: 0.7325
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7082 - loss: 0.5658 - val_accuracy: 0.5822 - val_loss: 0.7332
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7232 - loss: 0.5570 - val_accuracy: 0.5984 - val_loss: 0.7456
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7153 - loss: 0.5580 - val_accuracy: 0.5946 - val_loss: 0.7359
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7135 - loss: 0.5568 - val_accuracy: 0.5849 - val_loss: 0.7428
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7164 - loss: 0.5567 - val_accuracy: 0.5763 - val_loss: 0.7466
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7061 - loss: 0.5681 - val_accuracy: 0.5704 - val_loss: 0.7436
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7091 - loss: 0.5704 - val_accuracy: 0.5741 - val_loss: 0.7470
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7040 - loss: 0.5688 - val_accuracy: 0.5951 - val_loss: 0.7351
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7161 - loss: 0.5558 - val_accuracy: 0.5898 - val_loss: 0.7557
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7077 - loss: 0.5601 - val_accuracy: 0.5941 - val_loss: 0.7611
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7216 - loss: 0.5523 - val_accuracy: 0.5908 - val_loss: 0.7510
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7222 - loss: 0.5507 - val_accuracy: 0.5898 - val_loss: 0.7483
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7214 - loss: 0.5471 - val_accuracy: 0.6011 - val_loss: 0.7538
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7284 - loss: 0.5417 - val_accuracy: 0.5919 - val_loss: 0.7566
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7225 - loss: 0.5485 - val_accuracy: 0.5957 - val_loss: 0.7470
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7237 - loss: 0.5462 - val_accuracy: 0.5919 - val_loss: 0.7772
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7093 - loss: 0.5512 - val_accuracy: 0.5898 - val_loss: 0.7797
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7157 - loss: 0.5510 - val_accuracy: 0.5892 - val_loss: 0.7826
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7196 - loss: 0.5462 - val_accuracy: 0.5968 - val_loss: 0.7911
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7252 - loss: 0.5407 - val_accuracy: 0.5930 - val_loss: 0.7892
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7220 - loss: 0.5453 - val_accuracy: 0.5957 - val_loss: 0.7830
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7232 - loss: 0.5464 - val_accuracy: 0.5968 - val_loss: 0.7676
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7275 - loss: 0.5357 - val_accuracy: 0.5849 - val_loss: 0.7740
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7238 - loss: 0.5446 - val_accuracy: 0.5935 - val_loss: 0.7675
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7308 - loss: 0.5352 - val_accuracy: 0.5930 - val_loss: 0.7598
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7332 - loss: 0.5367 - val_accuracy: 0.5838 - val_loss: 0.7552
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7251 - loss: 0.5390 - val_accuracy: 0.5930 - val_loss: 0.7554
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7300 - loss: 0.5377 - val_accuracy: 0.5854 - val_loss: 0.7551
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7201 - loss: 0.5444 - val_accuracy: 0.5973 - val_loss: 0.7490
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7234 - loss: 0.5405 - val_accuracy: 0.5919 - val_loss: 0.7431
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7360 - loss: 0.5316 - val_accuracy: 0.5865 - val_loss: 0.7478
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7349 - loss: 0.5342 - val_accuracy: 0.5811 - val_loss: 0.7387
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7338 - loss: 0.5378 - val_accuracy: 0.5892 - val_loss: 0.7345
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7282 - loss: 0.5378 - val_accuracy: 0.5908 - val_loss: 0.7372
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7189 - loss: 0.5464 - val_accuracy: 0.5914 - val_loss: 0.7593
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7227 - loss: 0.5469 - val_accuracy: 0.5898 - val_loss: 0.7644
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7114 - loss: 0.5487 - val_accuracy: 0.5919 - val_loss: 0.7800
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7227 - loss: 0.5442 - val_accuracy: 0.5930 - val_loss: 0.7877
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7262 - loss: 0.5370 - val_accuracy: 0.5941 - val_loss: 0.7807
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7228 - loss: 0.5447 - val_accuracy: 0.5892 - val_loss: 0.7670
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7230 - loss: 0.5383 - val_accuracy: 0.5978 - val_loss: 0.7899
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7229 - loss: 0.5379 - val_accuracy: 0.5995 - val_loss: 0.7909
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7271 - loss: 0.5414 - val_accuracy: 0.6000 - val_loss: 0.7781
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7249 - loss: 0.5376 - val_accuracy: 0.6032 - val_loss: 0.7899
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7279 - loss: 0.5369 - val_accuracy: 0.5876 - val_loss: 0.7949
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7238 - loss: 0.5361 - val_accuracy: 0.5962 - val_loss: 0.7943
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7330 - loss: 0.5312 - val_accuracy: 0.6016 - val_loss: 0.7873
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7241 - loss: 0.5361 - val_accuracy: 0.5908 - val_loss: 0.7996
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7322 - loss: 0.5273 - val_accuracy: 0.5930 - val_loss: 0.7903
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7260 - loss: 0.5308 - val_accuracy: 0.5984 - val_loss: 0.7992
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7299 - loss: 0.5316 - val_accuracy: 0.5957 - val_loss: 0.7887
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7357 - loss: 0.5224 - val_accuracy: 0.5968 - val_loss: 0.7889
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7357 - loss: 0.5238 - val_accuracy: 0.5919 - val_loss: 0.7857
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7294 - loss: 0.5342 - val_accuracy: 0.5860 - val_loss: 0.7820
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7333 - loss: 0.5347 - val_accuracy: 0.5989 - val_loss: 0.7614
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7273 - loss: 0.5321 - val_accuracy: 0.5838 - val_loss: 0.7761
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7302 - loss: 0.5302 - val_accuracy: 0.5854 - val_loss: 0.7724
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7344 - loss: 0.5275 - val_accuracy: 0.5827 - val_loss: 0.7561
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7316 - loss: 0.5292 - val_accuracy: 0.6005 - val_loss: 0.7526
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7274 - loss: 0.5365 - val_accuracy: 0.5822 - val_loss: 0.7542
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7215 - loss: 0.5381 - val_accuracy: 0.5978 - val_loss: 0.7661
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7248 - loss: 0.5341 - val_accuracy: 0.5838 - val_loss: 0.7877
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7229 - loss: 0.5398 - val_accuracy: 0.6011 - val_loss: 0.7862
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7186 - loss: 0.5406 - val_accuracy: 0.5984 - val_loss: 0.7861
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7193 - loss: 0.5399 - val_accuracy: 0.5925 - val_loss: 0.7752
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7139 - loss: 0.5414 - val_accuracy: 0.5881 - val_loss: 0.7759
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7110 - loss: 0.5424 - val_accuracy: 0.5978 - val_loss: 0.7809
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7142 - loss: 0.5444 - val_accuracy: 0.5860 - val_loss: 0.7774
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7279 - loss: 0.5307 - val_accuracy: 0.5930 - val_loss: 0.7869
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7268 - loss: 0.5344 - val_accuracy: 0.6054 - val_loss: 0.7660
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7263 - loss: 0.5288 - val_accuracy: 0.6011 - val_loss: 0.7671
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7228 - loss: 0.5315 - val_accuracy: 0.5898 - val_loss: 0.7586
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7305 - loss: 0.5267 - val_accuracy: 0.5914 - val_loss: 0.7826
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7353 - loss: 0.5268 - val_accuracy: 0.5989 - val_loss: 0.7890
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7323 - loss: 0.5273 - val_accuracy: 0.6000 - val_loss: 0.7751
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7234 - loss: 0.5356 - val_accuracy: 0.5898 - val_loss: 0.7598
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7304 - loss: 0.5348 - val_accuracy: 0.5968 - val_loss: 0.7567
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7225 - loss: 0.5318 - val_accuracy: 0.5973 - val_loss: 0.7760
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7325 - loss: 0.5332 - val_accuracy: 0.5957 - val_loss: 0.7786
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7327 - loss: 0.5226 - val_accuracy: 0.5962 - val_loss: 0.7784
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7252 - loss: 0.5276 - val_accuracy: 0.5946 - val_loss: 0.7817
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7403 - loss: 0.5203 - val_accuracy: 0.5881 - val_loss: 0.7810
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7352 - loss: 0.5222 - val_accuracy: 0.5865 - val_loss: 0.7629
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7380 - loss: 0.5222 - val_accuracy: 0.5871 - val_loss: 0.7970
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7342 - loss: 0.5255 - val_accuracy: 0.5871 - val_loss: 0.7747
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7336 - loss: 0.5259 - val_accuracy: 0.5898 - val_loss: 0.7628
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7297 - loss: 0.5260 - val_accuracy: 0.5865 - val_loss: 0.7629
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7227 - loss: 0.5329 - val_accuracy: 0.5730 - val_loss: 0.7680
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7148 - loss: 0.5385 - val_accuracy: 0.5725 - val_loss: 0.7777
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7209 - loss: 0.5365 - val_accuracy: 0.5768 - val_loss: 0.7721
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7288 - loss: 0.5368 - val_accuracy: 0.5806 - val_loss: 0.7847
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7222 - loss: 0.5376 - val_accuracy: 0.5951 - val_loss: 0.7872
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7208 - loss: 0.5348 - val_accuracy: 0.6070 - val_loss: 0.7880
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7233 - loss: 0.5325 - val_accuracy: 0.5989 - val_loss: 0.7886
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7281 - loss: 0.5290 - val_accuracy: 0.5984 - val_loss: 0.8000
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7222 - loss: 0.5312 - val_accuracy: 0.5935 - val_loss: 0.7892
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7143 - loss: 0.5494 - val_accuracy: 0.5860 - val_loss: 0.7910
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7206 - loss: 0.5420 - val_accuracy: 0.5790 - val_loss: 0.7904
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7190 - loss: 0.5403 - val_accuracy: 0.5908 - val_loss: 0.8051
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7106 - loss: 0.5547 - val_accuracy: 0.5747 - val_loss: 0.8125
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7114 - loss: 0.5597 - val_accuracy: 0.5795 - val_loss: 0.8094
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7031 - loss: 0.5630 - val_accuracy: 0.5898 - val_loss: 0.7575
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7051 - loss: 0.5589 - val_accuracy: 0.5871 - val_loss: 0.7695
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7064 - loss: 0.5586 - val_accuracy: 0.5903 - val_loss: 0.7904
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7140 - loss: 0.5420 - val_accuracy: 0.5941 - val_loss: 0.7554
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7194 - loss: 0.5435 - val_accuracy: 0.6011 - val_loss: 0.7871
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7155 - loss: 0.5415 - val_accuracy: 0.5962 - val_loss: 0.7820
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7176 - loss: 0.5442 - val_accuracy: 0.6005 - val_loss: 0.7838
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7231 - loss: 0.5355 - val_accuracy: 0.5903 - val_loss: 0.8077
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7251 - loss: 0.5355 - val_accuracy: 0.5968 - val_loss: 0.7914
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7225 - loss: 0.5341 - val_accuracy: 0.6027 - val_loss: 0.7861
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7284 - loss: 0.5244 - val_accuracy: 0.5930 - val_loss: 0.7650
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7280 - loss: 0.5238 - val_accuracy: 0.5957 - val_loss: 0.7943
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7237 - loss: 0.5302 - val_accuracy: 0.5957 - val_loss: 0.7946
# Integrated Model - Loss of the testing set: 0.8373, Accuracy: 0.5610
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
